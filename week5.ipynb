# %%
import turicreate as tc

# %%
songs = tc.SFrame('song_data.sframe')

# %%
songs
# Out:
# Columns:
# 	user_id	str
# 	song_id	str
# 	listen_count	int
# 	title	str
# 	artist	str
# 	song	str
#
# Rows: 1116609
#
# Data:
# +-------------------------------+--------------------+--------------+
# |            user_id            |      song_id       | listen_count |
# +-------------------------------+--------------------+--------------+
# | b80344d063b5ccb3212f76538f... | SOAKIMP12A8C130995 |      1       |
# | b80344d063b5ccb3212f76538f... | SOBBMDR12A8C13253B |      2       |
# | b80344d063b5ccb3212f76538f... | SOBXHDL12A81C204C0 |      1       |
# | b80344d063b5ccb3212f76538f... | SOBYHAJ12A6701BF1D |      1       |
# | b80344d063b5ccb3212f76538f... | SODACBL12A8C13C273 |      1       |
# | b80344d063b5ccb3212f76538f... | SODDNQT12A6D4F5F7E |      5       |
# | b80344d063b5ccb3212f76538f... | SODXRTY12AB0180F3B |      1       |
# | b80344d063b5ccb3212f76538f... | SOFGUAY12AB017B0A8 |      1       |
# | b80344d063b5ccb3212f76538f... | SOFRQTD12A81C233C0 |      1       |
# ...

# %%
print(songs['user_id'].unique())
# Out:
# ['c66c10a9567f0d82ff31441a9fd5063e5cd9dfe8', '279292bb36dbfc7f505e36ebf038c81eb1d1d63e', 'c067c22072a17d33310d7223d7b79f819e48cf42', 'f6c596a519698c97f1591ad89f540d76f6a04f1a', '696787172dd3f5169dc94deef97e427cee86147d', '3a7111f4cdf3c5a85fd4053e3cc2333562e1e0cb', '31f6fd9d9936adb9f7d0f157fd960c0a676ccfd6', '532e98155cbfd1e1a474a28ed96e59e50f7c5baf', 'ee43b175ed753b2e2bce806c903d4661ad351a91', 'e372c27f6cb071518ae500589ae02c126954c148', '83b1428917b47a6b130ed471b09033820be78a8c', '9b10c5b0569c679d9d7e258c37c0acb99cbbce02', '39487deef9345b1e22881245cabf4e7c53b6cf6e', '88325c1fc54d4227b223a7ca7c68c2bdc39df54b', '18325842a941bc58449ee71d659a08d1c1bd2383', '3f2a5636078d12dab36f61f92efc1fc62f72f815', '75864fe1e1674afe546612ecfd2217f062610a79', 'b472a8e0407792249a28e8a24f0f82e6cc860822', 'b2b08a84654f90585e0dc3c5155d330fb8e4ba59', 'ca60f0fa15783aac3827a9edb2e1b51ef3a4fe19', '507433946f534f5d25ad1be302edb9a2376f503c', '2e9cbd200d67910aeb97b36efe9cd4341cc06030', '647811338b3bed47a2a374e7d0de
# ...

# %%
uni = songs['user_id'].unique()

# %%
len(uni)
# Out:
# 66346

# %%
songs_count =songs.groupby(key_column_names='artist',operations={'count': tc.aggregate.SUM('listen_count')})

# %%
songs_count.sort('count',False)
# Out:
# Columns:
# 	artist	str
# 	count	int
#
# Rows: 3375
#
# Data:
# +------------------------+-------+
# |         artist         | count |
# +------------------------+-------+
# |     Kings Of Leon      | 43218 |
# |     Dwight Yoakam      | 40619 |
# |         Björk          | 38889 |
# |        Coldplay        | 35362 |
# | Florence + The Machine | 33387 |
# |     Justin Bieber      | 29715 |
# |    Alliance Ethnik     | 26689 |
# |      OneRepublic       | 25754 |
# |         Train          | 25402 |
# |     The Black Keys     | 22184 |
# +------------------------+-------+
# [3375 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
songs.sort('listen_count',False)
# Out:
# Columns:
# 	user_id	str
# 	song_id	str
# 	listen_count	int
# 	title	str
# 	artist	str
# 	song	str
#
# Rows: 1116609
#
# Data:
# +-------------------------------+--------------------+--------------+
# |            user_id            |      song_id       | listen_count |
# +-------------------------------+--------------------+--------------+
# | 50996bbabb6f7857bf0c801943... | SOUAGPQ12A8AE47B3A |     920      |
# | bb85bb79612e5373ac714fcd44... | SOZQSVB12A8C13C271 |     796      |
# | c012ec364329bb08cbe3e62fe7... | SOBONKR12A58A7A7E0 |     683      |
# | 70caceccaa745b6f7bc2898a15... | SOPREHY12AB01815F9 |     676      |
# | d2232ac7a1ec17b283b5dff243... | SOLGIWB12A58A77A05 |     649      |
# | f5363481018dc87e8b06f9451e... | SOVRIPE12A6D4FEA19 |     605      |
# | f1bdbb9fb7399b402a09fa1242... | SOZPMJT12AAF3B40D1 |     585      |
# | 70caceccaa745b6f7bc2898a15... | SOJCRUY12A67ADA4C2 |     553      |
# | 2be4e2736f580dd4fe7b489f67... | SOXBCZH12A67ADAD77 |     500      |
# ...

# %%
songs_count.sort('count',True)
# Out:
# Columns:
# 	artist	str
# 	count	int
#
# Rows: 3375
#
# Data:
# +-------------------------------+-------+
# |             artist            | count |
# +-------------------------------+-------+
# |        William Tabbert        |   14  |
# |         Reel Feelings         |   24  |
# | Beyoncé feat. Bun B and Sl... |   26  |
# |             Diplo             |   30  |
# |         Boggle Karaoke        |   30  |
# |         harvey summers        |   31  |
# |             Nâdiya            |   36  |
# | Kanye West / Talib Kweli /... |   38  |
# |        Aneta Langerova        |   38  |
# |          Jody Bernal          |   38  |
# +-------------------------------+-------+
# [3375 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
uni
# Out:
# dtype: str
# Rows: 66346
# ...

# %%
    uniq_users =songs.groupby(key_column_names='artist',operations={'uni': tc.aggregate.COUNT_DISTINCT('user_id')})

# %%
uniq_users
# Out:
# Columns:
# 	artist	str
# 	uni	int
#
# Rows: 3375
#
# Data:
# +-------------------------------+-----+
# |             artist            | uni |
# +-------------------------------+-----+
# |           The Dells           | 157 |
# |  Lil Jon / The East Side Boyz |  95 |
# | Tom Petty And The Heartbre... | 803 |
# |          Blackstreet          | 177 |
# |            Ratatat            | 569 |
# |             Shotta            |  29 |
# |            Airscape           |  58 |
# |             Mecano            |  67 |
# | Moimir Papalescu & The Nih... |  59 |
# |          Brad Paisley         | 667 |
# +-------------------------------+-----+
# [3375 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
uniq_users.sort('uni',False)
# Out:
# Columns:
# 	artist	str
# 	uni	int
#
# Rows: 3375
#
# Data:
# +------------------------+------+
# |         artist         | uni  |
# +------------------------+------+
# |     Kings Of Leon      | 7373 |
# |        Coldplay        | 6340 |
# |        Harmonia        | 5970 |
# |         Björk          | 5834 |
# | Florence + The Machine | 5615 |
# |         Train          | 5157 |
# |      OneRepublic       | 5100 |
# |     Dwight Yoakam      | 4806 |
# |    Alliance Ethnik     | 4067 |
# |         Eminem         | 3981 |
# +------------------------+------+
# [3375 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
uniq_users.sort('uni',False).print_rows(100,2)
# Out:
# +-------------------------------+------+
# |             artist            | uni  |
# +-------------------------------+------+
# |         Kings Of Leon         | 7373 |
# |            Coldplay           | 6340 |
# |            Harmonia           | 5970 |
# |             Björk             | 5834 |
# |     Florence + The Machine    | 5615 |
# |             Train             | 5157 |
# |          OneRepublic          | 5100 |
# |         Dwight Yoakam         | 4806 |
# |        Alliance Ethnik        | 4067 |
# |             Eminem            | 3981 |
# | Barry Tuckwell/Academy of ... | 3949 |
# |           Metallica           | 3889 |
# |            Cartola            | 3853 |
# |         Justin Bieber         | 3745 |
# |           Radiohead           | 3732 |
# |          Linkin Park          | 3682 |
# |          The Killers          | 3676 |
# |        Black Eyed Peas        | 3631 |
# |              Muse             | 3504 |
# |           Daft Punk           | 3433 |
# ...
